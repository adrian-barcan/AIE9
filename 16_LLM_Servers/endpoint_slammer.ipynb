# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/adrianbarcan/deployments/wawh7o9s"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x114117390>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x114115e50>
# Good question! It’s one of the most famous tongue‑twisters, and over the years it’s inspired both playful guess‑work and a little bit of “scientific” trivia.
#
# ---
#
# ## The classic answer
#
# > “A woodchuck would chuck as much wood as a woodchuck would chuck if a woodchuck could chuck wood.”
#
# That’s the tongue‑twister version and it never quite stops people laughing.
#
# ---
#
# ## The “real” (if a woodchuck could actually chuck wood)
#
# The answer is, of course, a *hypothetical* one—because woodchucks (also known as groundhogs) are burrowers, not lumberjacks. But in 1988, wildlife biologist Richard Thomas ‑ using a *powdered‑food* analogy and some simple volume math ‑ estimated that a woodchuck could move **about 700 pounds (≈320 kg)** of “wood” (or more realistically, soil) in the time it would take to build a typical burrow. That works out to roughly **300–400 cubic feet** of material, or about **700 pounds** of wood, if the chuck‑er could chuck it.
#
# > *“If a woodchuck could chuck wood, it would chuck roughly 700 pounds of it in a single day.”* – (Thomas, 1988)
#
# ---
#
# ## A quick sanity check
#
# - **Volume of a standard boulder**:  *
#   1 ft³ ≈ 0.0283 m³, so 300 ft³ ≈ 8.5 m³ – a lot of wood
# - **Weight**: 700 pounds ≈ 318 kg, roughly the weight of a fully grown adult woodchuck many times over.
#
# So, at least in theory… a woodchuck could chuck *a lot* of wood if it had the right motivation and no burrowing instinct.
#
# ---
#
# ### Bottom line
#
# - **Tongue‑twister answer:** As much wood as a woodchuck could chuck, if it could.
# - **“Scientific” estimate:** Roughly 700 pounds (≈320 kg) of wood in a day – if a woodchuck really had the urge to chuck.
#
# Either way, the classic line keeps the laughter and the curiosity alive!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 12: A playful answer:
#
# > If a wood‑chuck could chuck wood, it mi...
# Response 1: A woodchuck would’d chuck “as much wood as a woodchuck would...
# Response 16: In the grand, often–unfounded debate that has been recited b...
# Response 19: A classic tongue‑twister! The exact amount isn’t scientifica...
# Response 15: A classic tongue‑twister! The humor is that the question has...
# Response 17: A wood‑chuck, of course, wouldn’t leave a pile growing on it...
# Response 23: **Classic answer (the folkloric estimate)**
# A widely‑cited...
# Response 18: It’s a classic tongue‑twister more than a hard science probl...
# Response 22: A classic (and somewhat whimsical) answer is:
#
# > “A woodch...
# Response 7: Not to worry—the woodchuck’s “chuck‑power” isn’t a real scie...
# Response 4: The old tongue‑twister doesn’t give a precise number, but if...
# Response 6: 13,259 squares....
# Response 5: Sure thing! Here are five playful takes on the classic tongu...
# Response 11: A wood‑chuck would chuck, on the average, as much wood as a ...
# Response 14: If a woodchuck could chuck wood, it could chuck roughly **70...
# Response 8: **Answer (Rumored “Wood‑chuck’s Chuck‑Capacity”)**
#
# > *“If a...
# Response 21: The classic tongue‑twister goes:
#
# > “How much wood would a w...
# Response 13: **Answer (the classic tongue‑twister reply):**
#
# > “A woodchu...
# Response 24: **You Can’t Chuck It, You Can Only Move It!**
#
# The classic t...
# Response 9: The classic tongue‑twister usually settles on a playful figu...
# Response 20: The classic tongue‑twister *“How much wood would a wood‑chuc...
# Response 3: It’s one of those classic tongue‑twisters that never really ...
# Response 2: The classic tongue‑twister gets to the heart of some curious...
# Response 10: Here are **10 different ways to answer** the classic tongue‑...
